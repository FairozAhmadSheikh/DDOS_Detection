# %% [markdown]
# # **Day 8 – Deployment Notebook**
# This notebook prepares the ML & Neural Network DDoS detection models for deployment.
# - Save models
# - Export preprocessing pipeline
# - Build FastAPI inference service code
# - Package helper utilities

# %%
import joblib
from tensorflow.keras.models import load_model
print('Ready for deployment steps.')

# %% [markdown]
# ## Save Deployment Artifacts

# %%
print('Saving ML and NN models for deployment...')
# Uncomment these once models exist in environment
# joblib.dump(joblib.load('best_model.pkl'), 'deploy_ml_model.pkl')
# load_model('ddos_nn.h5').save('deploy_nn_model.h5')
# joblib.dump(joblib.load('scaler.pkl'), 'deploy_scaler.pkl')
# joblib.dump(joblib.load('feature_columns.pkl'), 'deploy_feature_columns.pkl')
print('Deployment artifacts saved.')

# %%
## Generate FastAPI Server Script (`main.py`)
